# %%
import pandas as pd
import os
from openpyxl import load_workbook

# Load Excel file
file_path = r"C:\Users\shres\Downloads\TUFTS 4 typess.xlsx"
xls = pd.ExcelFile(file_path)

# Create directories to store the output files

output_dir_freedom = r"C:\Users\shres\Downloads\Freedom_Worksheetssstt"
output_dir_attributes = r"C:\Users\shres\Downloads\Attributes_Worksheetssstt"
output_dir_start_end = r"C:\Users\shres\Downloads\Start_End_Worksheetsstst"
output_dir_others = r"C:\Users\shres\Downloads\Other_Worksheetssstt"


if not os.path.exists(output_dir_freedom):
    os.makedirs(output_dir_freedom)

if not os.path.exists(output_dir_attributes):
    os.makedirs(output_dir_attributes)

if not os.path.exists(output_dir_start_end):
    os.makedirs(output_dir_start_end)

if not os.path.exists(output_dir_others):
    os.makedirs(output_dir_others)

# Define the strings with leading and trailing spaces for table extraction
start_string = 'UNITED HEALTHCARE UNDERWRITING FULLY INSURED APPROVAL FORM - For Internal Use Only'
end_string = 'GRAND TOTAL'

# Iterate through each sheet in the Excel file
for sheet_name in xls.sheet_names:
    print(f"Processing sheet: {sheet_name}")
    
    # Read the sheet into a DataFrame
    df = pd.read_excel(file_path, sheet_name=sheet_name, header=None)
    
    # Check if both the start and end strings exist in the sheet
    if start_string in df.values and end_string in df.values:
        # Save the worksheet into a new Excel file in 'Start_End' folder
        output_file_path_start_end = os.path.join(output_dir_start_end, f"{sheet_name}.xlsx")
        df.to_excel(output_file_path_start_end, index=False, header=False)
        print(f"Worksheet with start and end strings saved to: {output_file_path_start_end}")
        continue  # Move to the next sheet
    
    # Check if "Freedom" exists in the first cell
    if df.iloc[0, 0].find("Freedom") != -1:
        # Save the worksheet into a new Excel file in 'Freedom' folder
        output_file_path_freedom = os.path.join(output_dir_freedom, f"{sheet_name}.xlsx")
        df.to_excel(output_file_path_freedom, index=False, header=False)
        print(f"Worksheet starting with 'Freedom' saved to: {output_file_path_freedom}")
        continue  # Move to the next sheet
    
    # Check if "Attributes" exists in the first cell
    if df.iloc[0, 0].find("Attributes") != -1:
        # Save the worksheet into a new Excel file in 'Attributes' folder
        output_file_path_attributes = os.path.join(output_dir_attributes, f"{sheet_name}.xlsx")
        df.to_excel(output_file_path_attributes, index=False, header=False)
        print(f"Worksheet starting with 'Attributes' saved to: {output_file_path_attributes}")
        continue  # Move to the next sheet
    
    # If none of the conditions are met, save the worksheet into a new Excel file in 'Other' folder
    output_file_path_others = os.path.join(output_dir_others, f"{sheet_name}.xlsx")
    df.to_excel(output_file_path_others, index=False, header=False)
    print(f"Worksheet saved to: {output_file_path_others}")
# Out:
# Processing sheet: Greater Noida Mental MNS0000192
# Worksheet with start and end strings saved to: C:\Users\shres\Downloads\Start_End_Worksheetsstst\Greater Noida Mental MNS0000192.xlsx
# Processing sheet: Penguin Publishing MNS0000456
# Worksheet with start and end strings saved to: C:\Users\shres\Downloads\Start_End_Worksheetsstst\Penguin Publishing MNS0000456.xlsx
# Processing sheet: SB Management Inc MNS4X12
# Worksheet with start and end strings saved to: C:\Users\shres\Downloads\Start_End_Worksheetsstst\SB Management Inc MNS4X12.xlsx
# Processing sheet: Twisted National MNS02x02
# Worksheet with start and end strings saved to: C:\Users\shres\Downloads\Start_End_Worksheetsstst\Twisted National MNS02x02.xlsx
# Processing sheet: Vandelay Industries MNS01x5
# Worksheet with start and end strings saved to: C:\Users\shres\Downloads\Start_End_Worksheetsstst\Vandelay Industries MNS01x5.xlsx
# Processing sheet: freedom1
# ...

# %%
import pandas as pd
import os
from openpyxl import load_workbook

# Load Excel file
file_path = r"C:\Users\shres\Downloads\TUFTS 4 typess.xlsx"
xls = pd.ExcelFile(file_path)

# Create directories to store the output files
output_dir_freedom = r"C:\Users\shres\Downloads\Freedom_Worksheetsssttd"
output_dir_attributes = r"C:\Users\shres\Downloads\Attributes_Worksheetsssttd"
output_dir_start_end = r"C:\Users\shres\Downloads\Start_End_Worksheetsststd"
output_dir_others = r"C:\Users\shres\Downloads\Other_Worksheetsssttd"

if not os.path.exists(output_dir_freedom):
    os.makedirs(output_dir_freedom)

if not os.path.exists(output_dir_attributes):
    os.makedirs(output_dir_attributes)

if not os.path.exists(output_dir_start_end):
    os.makedirs(output_dir_start_end)

if not os.path.exists(output_dir_others):
    os.makedirs(output_dir_others)

# Define the strings with leading and trailing spaces for table extraction
start_string = 'UNITED HEALTHCARE UNDERWRITING FULLY INSURED APPROVAL FORM - For Internal Use Only'
end_string = 'GRAND TOTAL'

# Iterate through each sheet in the Excel file
for sheet_name in xls.sheet_names:
    print(f"Processing sheet: {sheet_name}")
    
    # Read the sheet into a DataFrame
    df = pd.read_excel(file_path, sheet_name=sheet_name, header=None)
    
    # Check if both the start and end strings exist in the sheet
    if start_string in df.values and end_string in df.values:
        # Save the entire worksheet into a new Excel file in 'Start_End' folder
        output_file_path_start_end = os.path.join(output_dir_start_end, f"{sheet_name}.xlsx")
        df.to_excel(output_file_path_start_end, index=False, header=False)
        print(f"Worksheet with start and end strings saved to: {output_file_path_start_end}")
        continue  # Move to the next sheet
    
    # Check if "Freedom" exists in the first cell
    if df.iloc[0, 0].find("Freedom") != -1:
        # Save the entire worksheet into a new Excel file in 'Freedom' folder
        output_file_path_freedom = os.path.join(output_dir_freedom, f"{sheet_name}.xlsx")
        df.to_excel(output_file_path_freedom, index=False, header=False)
        print(f"Worksheet starting with 'Freedom' saved to: {output_file_path_freedom}")
        continue  # Move to the next sheet
    
    # Check if "Attributes" exists in the first cell
    if df.iloc[0, 0].find("Attributes") != -1:
        # Save the entire worksheet into a new Excel file in 'Attributes' folder
        output_file_path_attributes = os.path.join(output_dir_attributes, f"{sheet_name}.xlsx")
        df.to_excel(output_file_path_attributes, index=False, header=False)
        print(f"Worksheet starting with 'Attributes' saved to: {output_file_path_attributes}")
        continue  # Move to the next sheet
    
    # If none of the conditions are met, save the entire worksheet into a new Excel file in 'Other' folder
    output_file_path_others = os.path.join(output_dir_others, f"{sheet_name}.xlsx")
    df.to_excel(output_file_path_others, index=False, header=False)
    print(f"Worksheet saved to: {output_file_path_others}")
# Out:
# Processing sheet: Greater Noida Mental MNS0000192
# Worksheet with start and end strings saved to: C:\Users\shres\Downloads\Start_End_Worksheetsststd\Greater Noida Mental MNS0000192.xlsx
# Processing sheet: Penguin Publishing MNS0000456
# Worksheet with start and end strings saved to: C:\Users\shres\Downloads\Start_End_Worksheetsststd\Penguin Publishing MNS0000456.xlsx
# Processing sheet: SB Management Inc MNS4X12
# Worksheet with start and end strings saved to: C:\Users\shres\Downloads\Start_End_Worksheetsststd\SB Management Inc MNS4X12.xlsx
# Processing sheet: Twisted National MNS02x02
# Worksheet with start and end strings saved to: C:\Users\shres\Downloads\Start_End_Worksheetsststd\Twisted National MNS02x02.xlsx
# Processing sheet: Vandelay Industries MNS01x5
# Worksheet with start and end strings saved to: C:\Users\shres\Downloads\Start_End_Worksheetsststd\Vandelay Industries MNS01x5.xlsx
# Processing sheet: freedom1
# ...
